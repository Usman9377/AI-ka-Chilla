# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv("iran_gdp.csv")

# %%
profile = ProfileReport(
    df,
    tsmode=True,
    title="Iran GDP Time Series"
)

profile.to_file("iran_year_profiling_report.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00,  7.32it/s]
