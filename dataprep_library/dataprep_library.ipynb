# %% [markdown]
# ## 🧹 DataPrep Library in Python — Definition
#
# **DataPrep** is a Python library designed to simplify and accelerate the **data preparation** process, especially during **exploratory data analysis (EDA)**. It provides fast, interactive, and user-friendly tools to **clean, explore, and visualize data** with minimal code.
#
# DataPrep is particularly useful for **data scientists, analysts, and machine learning practitioners** who want quick insights without writing complex visualization or preprocessing code.
#
# ---
#
# ## 🔧 Key Features
#
# - 🚀 **Fast EDA** with automatic data summaries
# - 📊 **Interactive visualizations** (built on Bokeh)
# - 🧼 **Data cleaning utilities**
# - 🕵️ **Missing value detection and analysis**
# - 📈 **Correlation and distribution analysis**
# - 🔍 **Exploration of structured and unstructured data**
#
# ---
#
# ## 📦 Main Modules
#
# | Module | Description |
# |------|-------------|
# | `dataprep.eda` | Tools for exploratory data analysis |
# | `dataprep.clean` | Functions for cleaning data |
# | `dataprep.connector` | Connects to databases and APIs |
# | `dataprep.datasets` | Sample datasets for practice |
#
# ---
#
# ## 📊 Common EDA Functions
#
# - `plot(df)` → Generates an automatic EDA report
# - `plot_correlation(df)` → Visualizes correlations
# - `plot_missing(df)` → Shows missing value patterns
# - `plot_distribution(df)` → Displays feature distributions
#
# ---
#
# ## 💡 Example Usage
#
# ```python
# from dataprep.eda import plot
# import pandas as pd
#
# df = pd.read_csv("data.csv")
# plot(df)

# %%
# import libraries
from pandas import read_csv
df = read_csv("iran_gdp.csv")
from dataprep.eda import create_report
create_report(df).show_browser()
# Out:
#   0%|          | 0/2647 [00:00<?, ?it/s]
# c:\Users\usman\miniconda3\envs\data_gathering\lib\site-packages\dask\core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))

# %%
# load dataset
from dataprep.eda import plot
import pandas as pd
plot(df)
